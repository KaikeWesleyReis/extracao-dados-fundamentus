# %% [markdown]
# # Objetivo
#
# Aqui vamos atuar em cima das bases mensais para calcular conceitos e avaliações fundamentalistas. São elas:
# - Graham atualizado por setor
# - Flag - Acima ou abaixo do preço de graham ajustado?
# - Flag - Acima ou abaixo do `DY %` médio do setor?
# - Flag - Acima de 10% de DY?
#
# ## Bibliotecas

# %%
# Geral
import warnings
import numpy as np
import pandas as pd

# Plots
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# Remover warnings chatos do pandas
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Calcular Preço de Graham Ajustado

# %%
def calcular_preco_graham_setor(pl, pvp, lpa, vpa):
    # Calcular valor
    val = pl * pvp * lpa * vpa
    if val > 0:
        return round(np.sqrt(val), 2)
    else:
        return np.nan

# %% [markdown]
# # Execução

# %%
# Carregar base(s)
df = pd.read_csv('dados/2_TRA/fundamentus_2023-11-02.csv')

# %% [markdown]
# **Agregados por setor necessários**

# %%
# Gerar agregados
df_agg = df[['SETOR', 'P_POR_L', 'P_POR_VP', 'DIV_YIELD']].groupby('SETOR').median().reset_index()

# %%
# Modificar colunas
df_agg.columns = [c if c == 'SETOR' else f'AGG_{c}' for c in df_agg.columns]

# %%
# Unificar informações na base
df = pd.merge(df, df_agg, on='SETOR', how='left')

# %%
# Calcular cotação de graham ajustada ao setor
df['COTACAO_GRAHAM_SETOR'] = df.apply(lambda x: calcular_preco_graham_setor(x['AGG_P_POR_L'],
                                                                            x['AGG_P_POR_VP'],
                                                                            x['LPA'],
                                                                            x['VPA']), axis=1)

# %%
# Criar razão - Acima indica um valor de cotação abaixo do que deveria
df['RAZAO_COTACAO_GRAHAM'] = (df['COTACAO_GRAHAM_SETOR']/df['COTACAO']).round(2)

# %% [markdown]
# **Criar Flags**

# %%
df['FLAG_MENOR_GRAHAM_SETOR'] = (df['COTACAO'] < df['COTACAO_GRAHAM_SETOR']).astype(int)

# %%
df['FLAG_DY_ACIMA_10'] = (df['DIV_YIELD'] >= 10).astype(int)

# %%
df['FLAG_DY_ACIMA_DY_SETOR'] = (df['DIV_YIELD'] >= df['AGG_DIV_YIELD']).astype(int)

# %%
df['FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR'] = (df['FLAG_DY_ACIMA_DY_SETOR'] == 1) & (df['FLAG_DY_ACIMA_DY_SETOR'] == 1)

# %% [markdown]
# **Avaliação de Carteira**

# %%
# Definir papeis atuais a partir da carteira e seus setores
papeis_atuais = ['BBAS3','ITSA3','EGIE3','TAEE4','PETR4','PRIO3','VALE3','TUPY3']
setores_atuais = df.loc[df['PAPEL'].isin(papeis_atuais), 'SETOR'].unique().tolist()

# %%
# Criar dataframe de análise
df_aval = df.loc[df['SETOR'].isin(setores_atuais)]

# %%
# Flag para apontar papeis de sua carteira
df_aval['CARTEIRA'] = df_aval['PAPEL'].isin(papeis_atuais).astype(int).copy()

# %%
# Definir colunas de analise
cols = ['PAPEL','SETOR','COTACAO','COTACAO_GRAHAM_SETOR', 'RAZAO_COTACAO_GRAHAM', 'DIV_YIELD','AGG_DIV_YIELD', 'P_POR_L']
cols += ['OSCILACOES_%_2023', 'LPA', 'VPA', 'MARG_EBIT', 'MARG_LIQUIDA']
cols += [c for c in df.columns if 'FLAG' in c]

# %%
# Visualizar
df_aval.loc[df_aval['CARTEIRA'] == 1, cols]
# Out:
#      PAPEL                            SETOR  COTACAO  COTACAO_GRAHAM_SETOR  \
# 155  TAEE4                 Energia Elétrica    11.27                  9.17
# 157  EGIE3                 Energia Elétrica    40.62                 21.60
# 210  BBAS3       Intermediários Financeiros    49.34                 68.82
# 218  ITSA3       Intermediários Financeiros     8.82                  9.01
# 283  TUPY3           Material de Transporte    24.91                 22.39
# 291  VALE3                        Mineração    62.68                 50.97
# 303  PETR4  Petróleo, Gás e Biocombustíveis    37.85                 49.10
# 306  PRIO3  Petróleo, Gás e Biocombustíveis    49.70                 18.98
#
#      RAZAO_COTACAO_GRAHAM  DIV_YIELD  AGG_DIV_YIELD  P_POR_L  \
# 155                  0.81       10.0           6.80     9.97
# 157                  0.53        8.7           6.80    10.23
# 210                  1.39        9.3           6.55     4.27
# 218                  1.02        7.8           6.55     6.45
# 283                  0.90        3.0           2.95     7.93
# 291                  0.81        6.5          12.70     5.00
# 303                  1.30       24.4           1.35     3.16
# 306                  0.38        0.0           1.35    11.85
#
#      OSCILACOES_%_2023    LPA    VPA  MARG_EBIT  MARG_LIQUIDA  \
# 155               2.98   1.13   6.47       63.1          49.8
# 157              14.38   3.97  10.22       46.6          28.5
# 210              52.02  11.55  54.86        NaN           0.0
# 218               4.08   1.37   7.92       14.1         175.5
# 283              -5.31   3.14  21.56        8.2           4.2
# 291             -26.08  12.54  41.20       37.8          27.8
# 303              90.66  11.99  28.42       45.0          27.0
# 306              33.57   4.20  12.12       57.3          46.0
#
#      FLAG_MENOR_GRAHAM_SETOR  FLAG_DY_ACIMA_10  FLAG_DY_ACIMA_DY_SETOR  \
# 155                        0                 1                       1
# 157                        0                 0                       1
# 210                        1                 0                       1
# 218                        1                 0                       1
# 283                        0                 0                       1
# 291                        0                 0                       0
# 303                        1                 1                       1
# 306                        0                 0                       0
#
#      FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR
# 155                              True
# 157                              True
# 210                              True
# 218                              True
# 283                              True
# 291                             False
# 303                              True
# 306                             False

# %%
df_viz[cols]
# Out:
#       PAPEL                       SETOR  COTACAO  COTACAO_GRAHAM_SETOR  \
# 206   MERC4  Intermediários Financeiros     7.16                   NaN
# 207  BRBI11  Intermediários Financeiros    11.65                   NaN
# 208   BNBR3  Intermediários Financeiros    93.06                148.53
# 209   BAZA3  Intermediários Financeiros    86.89                127.39
# 210   BBAS3  Intermediários Financeiros    49.34                 68.82
# 211   BMEB4  Intermediários Financeiros    11.64                 16.03
# 212   ABCB4  Intermediários Financeiros    19.35                 25.30
# 213   PINE4  Intermediários Financeiros     3.53                  4.62
# 214   BGIP4  Intermediários Financeiros    22.36                 31.05
# 215   BMEB3  Intermediários Financeiros    13.47                 16.03
# 216   ITSA4  Intermediários Financeiros     8.74                  9.01
# 217   BRSR6  Intermediários Financeiros    11.00                 17.90
# 218   ITSA3  Intermediários Financeiros     8.82                  9.01
# 219   BRSR3  Intermediários Financeiros    11.65                 17.90
# 220   ITUB3  Intermediários Financeiros    23.13                 20.46
# 221   BGIP3  Intermediários Financeiros    27.06                 31.05
# 222   PINE3  Intermediários Financeiros     4.16                  4.62
# 223   BEES3  Intermediários Financeiros     8.56                  7.21
# 224   ITUB4  Intermediários Financeiros    26.96                 20.46
# 225   BBDC3  Intermediários Financeiros    12.45                 12.74
# 226   BMIN4  Intermediários Financeiros    15.99                 20.13
# 227   BEES4  Intermediários Financeiros     9.61                  7.21
# 228   BBDC4  Intermediários Financeiros    14.16                 12.74
# 229   BRIV3  Intermediários Financeiros    10.53                 12.72
# 230   BRIV4  Intermediários Financeiros    10.51                 12.72
# 231   BRSR5  Intermediários Financeiros    18.20                 17.90
# 232   BMGB4  Intermediários Financeiros     2.35                  3.36
# 233   SANB3  Intermediários Financeiros    12.35                  9.90
# 234   RPAD5  Intermediários Financeiros     7.80                  8.31
# 235   RPAD3  Intermediários Financeiros     7.76                  8.31
# 236   BPAC5  Intermediários Financeiros     7.79                  4.71
# 237  SANB11  Intermediários Financeiros    26.21                 19.79
# 238   RPAD6  Intermediários Financeiros     7.60                  8.31
# 239   BMIN3  Intermediários Financeiros    23.92                 20.13
# 240   SANB4  Intermediários Financeiros    13.84                  9.90
# 241  BPAC11  Intermediários Financeiros    29.23                 14.12
# 242   BPAN4  Intermediários Financeiros     7.61                  5.00
# 245   BPAC3  Intermediários Financeiros    13.26                  4.71
# 246   CRIV3  Intermediários Financeiros     5.70                  4.38
# 247   CRIV4  Intermediários Financeiros     5.65                  4.38
#
#      RAZAO_COTACAO_GRAHAM  DIV_YIELD  AGG_DIV_YIELD  P_POR_L  \
# 206                   NaN        6.3           6.55   -35.86
# 207                   NaN        7.2           6.55     0.00
# 208                  1.60        6.7           6.55     3.60
# 209                  1.47        6.4           6.55     3.90
# 210                  1.39        9.3           6.55     4.27
# 211                  1.38        6.9           6.55     4.46
# 212                  1.31        6.2           6.55     5.42
# 213                  1.31        4.6           6.55     6.18
# 214                  1.39       15.3           6.55     6.13
# 215                  1.19        5.4           6.55     5.16
# 216                  1.03        7.9           6.55     6.39
# 217                  1.63        8.6           6.55     5.90
# 218                  1.02        7.8           6.55     6.45
# 219                  1.54        8.1           6.55     6.25
# 220                  0.88        6.5           6.55     7.18
# 221                  1.15       11.5           6.55     7.42
# 222                  1.11        0.0           6.55     7.28
# 223                  0.84        7.3           6.55     8.12
# 224                  0.76        5.5           6.55     8.37
# 225                  1.02        7.4           6.55     8.58
# 226                  1.26        9.9           6.55     8.23
# 227                  0.75        6.5           6.55     9.11
# 228                  0.90        7.1           6.55     9.76
# 229                  1.21        1.5           6.55     9.31
# 230                  1.21        6.1           6.55     9.29
# 231                  0.98        5.3           6.55     9.76
# 232                  1.43       16.4           6.55    10.17
# 233                  0.80        6.6           6.55    10.57
# 234                  1.07        7.4           6.55    10.85
# 235                  1.07        0.0           6.55    10.80
# 236                  0.60        3.2           6.55    10.66
# 237                  0.76        6.6           6.55    11.21
# 238                  1.09        0.0           6.55    10.57
# 239                  0.84        5.9           6.55    12.31
# 240                  0.72        6.5           6.55    11.84
# 241                  0.48        2.5           6.55    13.34
# 242                  0.66        3.4           6.55    14.18
# 245                  0.36        1.9           6.55    18.15
# 246                  0.77        0.0           6.55    22.45
# 247                  0.78        8.5           6.55    22.25
#
#      OSCILACOES_%_2023    LPA     VPA  MARG_EBIT  MARG_LIQUIDA  \
# 206               1.10  -0.20   13.81        NaN           0.0
# 207               2.87   0.00    0.00        NaN           NaN
# 208              32.07  25.85  114.19        NaN           0.0
# 209              85.77  22.28   97.45        NaN           0.0
# 210              52.02  11.55   54.86        NaN           0.0
# 211              23.02   2.61   13.18        NaN           0.0
# 212               5.04   3.57   23.98        NaN           0.0
# 213             127.05   0.57    5.02        NaN           0.0
# 214              46.85   3.65   35.35        NaN           0.0
# 215              41.09   2.61   13.18        NaN           0.0
# 216               7.95   1.37    7.92       14.1         175.5
# 217              21.19   1.86   23.04        NaN           0.0
# 218               4.08   1.37    7.92       14.1         175.5
# 219              15.78   1.86   23.04        NaN           0.0
# 220               9.64   3.22   17.40        NaN           0.0
# 221              15.05   3.65   35.35        NaN           0.0
# 222             194.10   0.57    5.02        NaN           0.0
# 223              64.82   1.05    6.63        NaN           0.0
# 224              11.15   3.22   17.40        NaN           0.0
# 225              -2.23   1.45   14.97        NaN           0.0
# 226              32.27   1.94   27.96        NaN           0.0
# 227              55.84   1.05    6.63        NaN           0.0
# 228              -1.27   1.45   14.97        NaN           0.0
# 229              14.37   1.13   19.17        NaN           0.0
# 230              19.40   1.13   19.17        NaN           0.0
# 231               8.46   1.86   23.04        NaN           0.0
# 232               7.72   0.23    6.58        NaN           0.0
# 233              -2.18   1.17   11.20        NaN           0.0
# 234              21.98   0.72   12.83        NaN           0.0
# 235               8.68   0.72   12.83        NaN           0.0
# 236              42.14   0.73    4.06        NaN           0.0
# 237              -2.12   2.34   22.40        NaN           0.0
# 238              13.60   0.72   12.83        NaN           0.0
# 239              31.24   1.94   27.96        NaN           0.0
# 240              -2.55   1.17   11.20        NaN           0.0
# 241              24.08   2.19   12.18        NaN           0.0
# 242              25.37   0.54    6.20        NaN           0.0
# 245               3.72   0.73    4.06        NaN           0.0
# 246              10.04   0.25   10.29        NaN           0.0
# 247              18.51   0.25   10.29        NaN           0.0
#
#      FLAG_MENOR_GRAHAM_SETOR  FLAG_DY_ACIMA_10  FLAG_DY_ACIMA_DY_SETOR  \
# 206                        0                 0                       0
# 207                        0                 0                       1
# 208                        1                 0                       1
# 209                        1                 0                       0
# 210                        1                 0                       1
# 211                        1                 0                       1
# 212                        1                 0                       0
# 213                        1                 0                       0
# 214                        1                 1                       1
# 215                        1                 0                       0
# 216                        1                 0                       1
# 217                        1                 0                       1
# 218                        1                 0                       1
# 219                        1                 0                       1
# 220                        0                 0                       0
# 221                        1                 1                       1
# 222                        1                 0                       0
# 223                        0                 0                       1
# 224                        0                 0                       0
# 225                        1                 0                       1
# 226                        1                 0                       1
# 227                        0                 0                       0
# 228                        0                 0                       1
# 229                        1                 0                       0
# 230                        1                 0                       0
# 231                        0                 0                       0
# 232                        1                 1                       1
# 233                        0                 0                       1
# 234                        1                 0                       1
# 235                        1                 0                       0
# 236                        0                 0                       0
# 237                        0                 0                       1
# 238                        1                 0                       0
# 239                        0                 0                       0
# 240                        0                 0                       0
# 241                        0                 0                       0
# 242                        0                 0                       0
# 245                        0                 0                       0
# 246                        0                 0                       0
# 247                        0                 0                       1
#
#      FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR
# 206                             False
# 207                              True
# 208                              True
# 209                             False
# 210                              True
# 211                              True
# 212                             False
# 213                             False
# 214                              True
# 215                             False
# 216                              True
# 217                              True
# 218                              True
# 219                              True
# 220                             False
# 221                              True
# 222                             False
# 223                              True
# 224                             False
# 225                              True
# 226                              True
# 227                             False
# 228                              True
# 229                             False
# 230                             False
# 231                             False
# 232                              True
# 233                              True
# 234                              True
# 235                             False
# 236                             False
# 237                              True
# 238                             False
# 239                             False
# 240                             False
# 241                             False
# 242                             False
# 245                             False
# 246                             False
# 247                              True

# %%
# Gráfico Setorial 1 - P_POR_L (Anos de retorno de investimento via lucro) x DIV_YIELD (%)
# Definir dataframe para visualizar
cond = (df_aval['SETOR'] == setores_atuais[2]) & (df_aval['DIV_YIELD'] < 1000) & (df_aval['COTACAO_GRAHAM_SETOR'].notnull())
df_viz = df_aval[cond].copy()

fig = px.scatter(data_frame=df_viz, x='P_POR_VP', y='DIV_YIELD',
                 hover_data=['AGG_DIV_YIELD','PAPEL','COTACAO_GRAHAM_SETOR','COTACAO'], color='FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR')
fig.show()
# Out:
# <div>                            <div id="73a25f67-60f2-46ba-bbd4-55e5a114e9ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73a25f67-60f2-46ba-bbd4-55e5a114e9ad")) {                    Plotly.newPlot(                        "73a25f67-60f2-46ba-bbd4-55e5a114e9ad",                        [{"customdata":[[2.95,"POMO3",4.34,4.13],[2.95,"RAPT3",9.78,9.42],[2.95,"RSUL4",46.0,75.0],[2.95,"POMO4",4.34,5.3],[2.95,"RAPT4",9.78,11.06],[2.95,"TUPY3",22.39,24.91]],"hovertemplate":"FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR=True<br>P_POR_VP=%{x}<br>DIV_YIELD=%{y}<br>AGG_DIV_YIELD=%{customdata[0]}<br>PAPEL=%{customdata[1]}<br>COTACAO_GRAHAM_SETOR=%{customdata[2]}<br>COTACAO=%{customdata[3]}<extra></extra>","legendgroup":"True","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"True","orientation":"v","showlegend":true,"x":[1.2,1.06,2.82,1.54,1.24,1.16],"xaxis":"x","y":[9.1,5.4,3.8,7.1,4.6,3.0],"yaxis":"y","type":"scatter"},{"customdata":[[2.95,"FRAS3",7.53,14.56]],"hovertemplate":"FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR=False<br>P_POR_VP=%{x}<br>DIV_YIELD=%{y}<br>AGG_DIV_YIELD=%{customdata[0]}<br>PAPEL=%{customdata[1]}<br>COTACAO_GRAHAM_SETOR=%{customdata[2]}<br>COTACAO=%{customdata[3]}<extra></extra>","legendgroup":"False","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":[2.07],"xaxis":"x","y":[2.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %%
# Gráfico Setorial 1 - P_POR_L (Anos de retorno de investimento via lucro) x DIV_YIELD (%)
# Definir dataframe para visualizar
cond = (df_aval['SETOR'] == setores_atuais[1]) & (df_aval['DIV_YIELD'] < 1000) & (df_aval['COTACAO_GRAHAM_SETOR'].notnull())
df_viz = df_aval[cond].copy()

fig = px.scatter(data_frame=df_viz, x='P_POR_L', y='DIV_YIELD',
                 hover_data=['AGG_DIV_YIELD','PAPEL','COTACAO_GRAHAM_SETOR','COTACAO'], color='FLAG_MENOR_GRAHAM_ACIMA_DY_SETOR')
fig.show()

# %%
df_viz[cols].sort_values('DIV_YIELD')
# Out:
#       PAPEL                       SETOR  COTACAO  COTACAO_GRAHAM_SETOR  \
# 222   PINE3  Intermediários Financeiros     4.16                  4.62
# 235   RPAD3  Intermediários Financeiros     7.76                  8.31
# 246   CRIV3  Intermediários Financeiros     5.70                  4.38
# 238   RPAD6  Intermediários Financeiros     7.60                  8.31
# 229   BRIV3  Intermediários Financeiros    10.53                 12.72
# 245   BPAC3  Intermediários Financeiros    13.26                  4.71
# 241  BPAC11  Intermediários Financeiros    29.23                 14.12
# 236   BPAC5  Intermediários Financeiros     7.79                  4.71
# 242   BPAN4  Intermediários Financeiros     7.61                  5.00
# 213   PINE4  Intermediários Financeiros     3.53                  4.62
# 231   BRSR5  Intermediários Financeiros    18.20                 17.90
# 215   BMEB3  Intermediários Financeiros    13.47                 16.03
# 224   ITUB4  Intermediários Financeiros    26.96                 20.46
# 239   BMIN3  Intermediários Financeiros    23.92                 20.13
# 230   BRIV4  Intermediários Financeiros    10.51                 12.72
# 212   ABCB4  Intermediários Financeiros    19.35                 25.30
# 206   MERC4  Intermediários Financeiros     7.16                   NaN
# 209   BAZA3  Intermediários Financeiros    86.89                127.39
# 220   ITUB3  Intermediários Financeiros    23.13                 20.46
# 240   SANB4  Intermediários Financeiros    13.84                  9.90
# 227   BEES4  Intermediários Financeiros     9.61                  7.21
# 237  SANB11  Intermediários Financeiros    26.21                 19.79
# 233   SANB3  Intermediários Financeiros    12.35                  9.90
# 208   BNBR3  Intermediários Financeiros    93.06                148.53
# 211   BMEB4  Intermediários Financeiros    11.64                 16.03
# 228   BBDC4  Intermediários Financeiros    14.16                 12.74
# 207  BRBI11  Intermediários Financeiros    11.65                   NaN
# 223   BEES3  Intermediários Financeiros     8.56                  7.21
# 225   BBDC3  Intermediários Financeiros    12.45                 12.74
# 234   RPAD5  Intermediários Financeiros     7.80                  8.31
# 218   ITSA3  Intermediários Financeiros     8.82                  9.01
# 216   ITSA4  Intermediários Financeiros     8.74                  9.01
# 219   BRSR3  Intermediários Financeiros    11.65                 17.90
# 247   CRIV4  Intermediários Financeiros     5.65                  4.38
# 217   BRSR6  Intermediários Financeiros    11.00                 17.90
# 210   BBAS3  Intermediários Financeiros    49.34                 68.82
# 226   BMIN4  Intermediários Financeiros    15.99                 20.13
# 221   BGIP3  Intermediários Financeiros    27.06                 31.05
# 214   BGIP4  Intermediários Financeiros    22.36                 31.05
# 232   BMGB4  Intermediários Financeiros     2.35                  3.36
# 244   BSLI3  Intermediários Financeiros    12.61                  6.06
# 243   BSLI4  Intermediários Financeiros    11.94                  6.06
#
#      RAZAO_COTACAO_GRAHAM  DIV_YIELD  AGG_DIV_YIELD  P_POR_L  \
# 222                  1.11        0.0           6.55     7.28
# 235                  1.07        0.0           6.55    10.80
# 246                  0.77        0.0           6.55    22.45
# 238                  1.09        0.0           6.55    10.57
# 229                  1.21        1.5           6.55     9.31
# 245                  0.36        1.9           6.55    18.15
# 241                  0.48        2.5           6.55    13.34
# 236                  0.60        3.2           6.55    10.66
# 242                  0.66        3.4           6.55    14.18
# 213                  1.31        4.6           6.55     6.18
# 231                  0.98        5.3           6.55     9.76
# 215                  1.19        5.4           6.55     5.16
# 224                  0.76        5.5           6.55     8.37
# 239                  0.84        5.9           6.55    12.31
# 230                  1.21        6.1           6.55     9.29
# 212                  1.31        6.2           6.55     5.42
# 206                   NaN        6.3           6.55   -35.86
# 209                  1.47        6.4           6.55     3.90
# 220                  0.88        6.5           6.55     7.18
# 240                  0.72        6.5           6.55    11.84
# 227                  0.75        6.5           6.55     9.11
# 237                  0.76        6.6           6.55    11.21
# 233                  0.80        6.6           6.55    10.57
# 208                  1.60        6.7           6.55     3.60
# 211                  1.38        6.9           6.55     4.46
# 228                  0.90        7.1           6.55     9.76
# 207                   NaN        7.2           6.55     0.00
# 223                  0.84        7.3           6.55     8.12
# 225                  1.02        7.4           6.55     8.58
# 234                  1.07        7.4           6.55    10.85
# 218                  1.02        7.8           6.55     6.45
# 216                  1.03        7.9           6.55     6.39
# 219                  1.54        8.1           6.55     6.25
# 247                  0.78        8.5           6.55    22.25
# 217                  1.63        8.6           6.55     5.90
# 210                  1.39        9.3           6.55     4.27
# 226                  1.26        9.9           6.55     8.23
# 221                  1.15       11.5           6.55     7.42
# 214                  1.39       15.3           6.55     6.13
# 232                  1.43       16.4           6.55    10.17
# 244                  0.48     1110.5           6.55    16.99
# 243                  0.51     1290.1           6.55    16.09
#
#      OSCILACOES_%_2023    LPA     VPA  MARG_EBIT  MARG_LIQUIDA  \
# 222             194.10   0.57    5.02        NaN           0.0
# 235               8.68   0.72   12.83        NaN           0.0
# 246              10.04   0.25   10.29        NaN           0.0
# 238              13.60   0.72   12.83        NaN           0.0
# 229              14.37   1.13   19.17        NaN           0.0
# 245               3.72   0.73    4.06        NaN           0.0
# 241              24.08   2.19   12.18        NaN           0.0
# 236              42.14   0.73    4.06        NaN           0.0
# 242              25.37   0.54    6.20        NaN           0.0
# 213             127.05   0.57    5.02        NaN           0.0
# 231               8.46   1.86   23.04        NaN           0.0
# 215              41.09   2.61   13.18        NaN           0.0
# 224              11.15   3.22   17.40        NaN           0.0
# 239              31.24   1.94   27.96        NaN           0.0
# 230              19.40   1.13   19.17        NaN           0.0
# 212               5.04   3.57   23.98        NaN           0.0
# 206               1.10  -0.20   13.81        NaN           0.0
# 209              85.77  22.28   97.45        NaN           0.0
# 220               9.64   3.22   17.40        NaN           0.0
# 240              -2.55   1.17   11.20        NaN           0.0
# 227              55.84   1.05    6.63        NaN           0.0
# 237              -2.12   2.34   22.40        NaN           0.0
# 233              -2.18   1.17   11.20        NaN           0.0
# 208              32.07  25.85  114.19        NaN           0.0
# 211              23.02   2.61   13.18        NaN           0.0
# 228              -1.27   1.45   14.97        NaN           0.0
# 207               2.87   0.00    0.00        NaN           NaN
# 223              64.82   1.05    6.63        NaN           0.0
# 225              -2.23   1.45   14.97        NaN           0.0
# 234              21.98   0.72   12.83        NaN           0.0
# 218               4.08   1.37    7.92       14.1         175.5
# 216               7.95   1.37    7.92       14.1         175.5
# 219              15.78   1.86   23.04        NaN           0.0
# 247              18.51   0.25   10.29        NaN           0.0
# 217              21.19   1.86   23.04        NaN           0.0
# 210              52.02  11.55   54.86        NaN           0.0
# 226              32.27   1.94   27.96        NaN           0.0
# 221              15.05   3.65   35.35        NaN           0.0
# 214              46.85   3.65   35.35        NaN           0.0
# 232               7.72   0.23    6.58        NaN           0.0
# 244             -29.38   0.74    6.63        NaN           0.0
# 243             -16.10   0.74    6.63        NaN           0.0
#
#      FLAG_MENOR_GRAHAM_SETOR  FLAG_DY_ACIMA_10  FLAG_DY_ACIMA_DY_SETOR
# 222                        1                 0                       0
# 235                        1                 0                       0
# 246                        0                 0                       0
# 238                        1                 0                       0
# 229                        1                 0                       0
# 245                        0                 0                       0
# 241                        0                 0                       0
# 236                        0                 0                       0
# 242                        0                 0                       0
# 213                        1                 0                       0
# 231                        0                 0                       0
# 215                        1                 0                       0
# 224                        0                 0                       0
# 239                        0                 0                       0
# 230                        1                 0                       0
# 212                        1                 0                       0
# 206                        0                 0                       0
# 209                        1                 0                       0
# 220                        0                 0                       0
# 240                        0                 0                       0
# 227                        0                 0                       0
# 237                        0                 0                       1
# 233                        0                 0                       1
# 208                        1                 0                       1
# 211                        1                 0                       1
# 228                        0                 0                       1
# 207                        0                 0                       1
# 223                        0                 0                       1
# 225                        1                 0                       1
# 234                        1                 0                       1
# 218                        1                 0                       1
# 216                        1                 0                       1
# 219                        1                 0                       1
# 247                        0                 0                       1
# 217                        1                 0                       1
# 210                        1                 0                       1
# 226                        1                 0                       1
# 221                        1                 1                       1
# 214                        1                 1                       1
# 232                        1                 1                       1
# 244                        0                 1                       1
# 243                        0                 1                       1
